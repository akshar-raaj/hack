# %%
print 1
# Out:
# 1

# %%
uni_repr = u"abc"
str_repr = "abc"
uni_accented = u"\xe4"

# %%
print uni_repr
# Out:
# abc

# %%
print str_repr, uni_accented
# Out:
# abc ä

# %%
f = open('uni_accented', 'w')
f.write(uni_accented)
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# <ipython-input-5-1dcd90947fe8> in <module>()
#       1 f = open('uni_accented', 'w')
# ----> 2 f.write(uni_accented)
#
# UnicodeEncodeError: 'ascii' codec can't encode character u'\xe4' in position 0: ordinal not in range(128)

# %%
f.close()

# %%
import sys

# %%
reload(sys).setdefaultencoding("utf8")

# %%
print uni_accented
